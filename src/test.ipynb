# %%
# You can follow this tutorial for more information - https://www.tutorialspoint.com/google_colab/index.htm
# You can also see this video - https://www.youtube.com/watch?v=inN8seMm7UI

# Mount your Drive - After doing this step, your Google Drive folders are accessible from Google Colab.
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# Use it as a standard Linux console, by prepending ! to the commands.

# Install all the requirements
# !pip install opencv-python
# !pip install pytorchvideo
# Example of apt-get
# !apt-get install protobuf-compiler python-pil python-lxml python-tk

# Example of setup Tensorflow version
# %tensorflow_version 2.x

# %%
# Move into the folder where you have the script test.py and all you need to run your test
# I downloaded the archive ONFIRE2023_Example_Code.zip in my Google Drive root /content/gdrive/My Drive/ but you can use different folders.
# %cd '/content/gdrive/My Drive/Team35'

# %%
# Run the test
# --videos is the path of the folder with the test videos. Use the provided foo_videos/ to check if your code works.
# --results is the path of the folder in which the predictions of your model should be written. A sample foo_results/ is provided.
# !python test.py --videos ../test_data/TEST_SET/ --results ../test_data/TEST_RESULTS/ --ground_truth ../test_data/GT_TEST_SET/ --model x3d_xs --clip_len 13 --clip_stride 10
# Out:
# Frost some blocks...
# --------------------------------------------------
# Processing video  Test_Video0.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 410
# Going to generate  51  clips
# --------------------------------------------------
# Processing video  Test_Video1.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 460
# Going to generate  57  clips
# --------------------------------------------------
# Processing video  Test_Video10.mp4
# --------------------------------------------------
# Frames per second = 59.94
# Total frames = 1500
# Going to generate  187  clips
# --------------------------------------------------
# Processing video  Test_Video100.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 883
# Going to generate  110  clips
# --------------------------------------------------
# Processing video  Test_Video101.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 265
# Going to generate  33  clips
# --------------------------------------------------
# Processing video  Test_Video102.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 487
# Going to generate  61  clips
# --------------------------------------------------
# Processing video  Test_Video103.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 450
# Going to generate  56  clips
# --------------------------------------------------
# Processing video  Test_Video104.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 305
# Going to generate  38  clips
# --------------------------------------------------
# Processing video  Test_Video105.mp4
# --------------------------------------------------
# Frames per second = 30.0
# Total frames = 423
# Going to generate  53  clips
# --------------------------------------------------
# Processing video  Test_Video106.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 278
# Going to generate  35  clips
# --------------------------------------------------
# Processing video  Test_Video107.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 300
# Going to generate  37  clips
# --------------------------------------------------
# Processing video  Test_Video108.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 260
# Going to generate  32  clips
# --------------------------------------------------
# Processing video  Test_Video109.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 691
# Going to generate  86  clips
# --------------------------------------------------
# Processing video  Test_Video11.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 617
# Going to generate  77  clips
# --------------------------------------------------
# Processing video  Test_Video110.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 699
# Going to generate  87  clips
# --------------------------------------------------
# Processing video  Test_Video111.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 420
# Going to generate  52  clips
# --------------------------------------------------
# Processing video  Test_Video112.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 665
# Going to generate  83  clips
# --------------------------------------------------
# Processing video  Test_Video113.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 490
# Going to generate  61  clips
# --------------------------------------------------
# Processing video  Test_Video114.mp4
# --------------------------------------------------
# Frames per second = 24.0
# Total frames = 450
# Going to generate  56  clips
# --------------------------------------------------
# Processing video  Test_Video115.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 488
# Going to generate  61  clips
# --------------------------------------------------
# Processing video  Test_Video116.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 234
# Going to generate  29  clips
# --------------------------------------------------
# Processing video  Test_Video117.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 432
# Going to generate  54  clips
# --------------------------------------------------
# Processing video  Test_Video118.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 259
# Going to generate  32  clips
# --------------------------------------------------
# Processing video  Test_Video119.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 219
# Going to generate  27  clips
# --------------------------------------------------
# Processing video  Test_Video12.mp4
# --------------------------------------------------
# Frames per second = 24.0
# Total frames = 518
# Going to generate  65  clips
# --------------------------------------------------
# Processing video  Test_Video120.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 298
# Going to generate  37  clips
# --------------------------------------------------
# Processing video  Test_Video121.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 447
# Going to generate  56  clips
# --------------------------------------------------
# Processing video  Test_Video122.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 451
# Going to generate  56  clips
# --------------------------------------------------
# Processing video  Test_Video123.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 502
# Going to generate  63  clips
# --------------------------------------------------
# Processing video  Test_Video124.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 358
# Going to generate  45  clips
# --------------------------------------------------
# Processing video  Test_Video125.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 300
# Going to generate  37  clips
# --------------------------------------------------
# Processing video  Test_Video126.mp4
# --------------------------------------------------
# Frames per second = 30.0
# Total frames = 301
# Going to generate  37  clips
# --------------------------------------------------
# Processing video  Test_Video127.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 331
# Going to generate  41  clips
# --------------------------------------------------
# Processing video  Test_Video128.mp4
# --------------------------------------------------
# Frames per second = 30.0
# Total frames = 310
# Going to generate  39  clips
# --------------------------------------------------
# Processing video  Test_Video129.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 329
# Going to generate  41  clips
# --------------------------------------------------
# Processing video  Test_Video13.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 620
# Going to generate  77  clips
# --------------------------------------------------
# Processing video  Test_Video130.mp4
# --------------------------------------------------
# Frames per second = 30.0
# Total frames = 750
# Going to generate  94  clips
# --------------------------------------------------
# Processing video  Test_Video131.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 750
# Going to generate  94  clips
# --------------------------------------------------
# Processing video  Test_Video132.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 675
# Going to generate  84  clips
# --------------------------------------------------
# Processing video  Test_Video133.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 600
# Going to generate  75  clips
# --------------------------------------------------
# Processing video  Test_Video134.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 135
# Going to generate  17  clips
# --------------------------------------------------
# Processing video  Test_Video135.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 633
# Going to generate  79  clips
# --------------------------------------------------
# Processing video  Test_Video136.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 200
# Going to generate  25  clips
# --------------------------------------------------
# Processing video  Test_Video137.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 622
# Going to generate  78  clips
# --------------------------------------------------
# Processing video  Test_Video138.mp4
# --------------------------------------------------
# Frames per second = 59.94
# Total frames = 3416
# Going to generate  427  clips
# --------------------------------------------------
# Processing video  Test_Video139.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 353
# Going to generate  44  clips
# --------------------------------------------------
# Processing video  Test_Video14.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 449
# Going to generate  56  clips
# --------------------------------------------------
# Processing video  Test_Video140.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 549
# Going to generate  68  clips
# --------------------------------------------------
# Processing video  Test_Video141.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 241
# Going to generate  30  clips
# --------------------------------------------------
# Processing video  Test_Video142.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 303
# Going to generate  38  clips
# --------------------------------------------------
# Processing video  Test_Video143.mp4
# --------------------------------------------------
# Frames per second = 50.0
# Total frames = 739
# Going to generate  92  clips
# --------------------------------------------------
# Processing video  Test_Video144.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 378
# Going to generate  47  clips
# --------------------------------------------------
# Processing video  Test_Video145.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 1174
# Going to generate  147  clips
# --------------------------------------------------
# Processing video  Test_Video146.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 519
# Going to generate  65  clips
# --------------------------------------------------
# Processing video  Test_Video147.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 630
# Going to generate  79  clips
# --------------------------------------------------
# Processing video  Test_Video148.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 278
# Going to generate  35  clips
# --------------------------------------------------
# Processing video  Test_Video15.mp4
# --------------------------------------------------
# Frames per second = 24.0
# Total frames = 206
# Going to generate  26  clips
# --------------------------------------------------
# Processing video  Test_Video16.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 267
# Going to generate  33  clips
# --------------------------------------------------
# Processing video  Test_Video17.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 750
# Going to generate  94  clips
# --------------------------------------------------
# Processing video  Test_Video18.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 335
# Going to generate  42  clips
# --------------------------------------------------
# Processing video  Test_Video19.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 510
# Going to generate  64  clips
# --------------------------------------------------
# Processing video  Test_Video2.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 332
# Going to generate  41  clips
# --------------------------------------------------
# Processing video  Test_Video20.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 426
# Going to generate  53  clips
# --------------------------------------------------
# Processing video  Test_Video21.mp4
# --------------------------------------------------
# Frames per second = 30.0
# Total frames = 801
# Going to generate  100  clips
# --------------------------------------------------
# Processing video  Test_Video22.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 212
# Going to generate  26  clips
# --------------------------------------------------
# Processing video  Test_Video23.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 189
# Going to generate  23  clips
# --------------------------------------------------
# Processing video  Test_Video24.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 722
# Going to generate  90  clips
# --------------------------------------------------
# Processing video  Test_Video25.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 775
# Going to generate  97  clips
# --------------------------------------------------
# Processing video  Test_Video26.mp4
# --------------------------------------------------
# Frames per second = 60.0
# Total frames = 1685
# Going to generate  210  clips
# --------------------------------------------------
# Processing video  Test_Video27.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 580
# Going to generate  72  clips
# --------------------------------------------------
# Processing video  Test_Video28.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 901
# Going to generate  112  clips
# --------------------------------------------------
# Processing video  Test_Video29.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 566
# Going to generate  71  clips
# --------------------------------------------------
# Processing video  Test_Video3.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 392
# Going to generate  49  clips
# --------------------------------------------------
# Processing video  Test_Video30.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 300
# Going to generate  37  clips
# --------------------------------------------------
# Processing video  Test_Video31.mp4
# --------------------------------------------------
# Frames per second = 24.0
# Total frames = 128
# Going to generate  16  clips
# --------------------------------------------------
# Processing video  Test_Video32.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 336
# Going to generate  42  clips
# --------------------------------------------------
# Processing video  Test_Video33.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 371
# Going to generate  46  clips
# --------------------------------------------------
# Processing video  Test_Video34.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 479
# Going to generate  60  clips
# --------------------------------------------------
# Processing video  Test_Video35.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 726
# Going to generate  91  clips
# --------------------------------------------------
# Processing video  Test_Video36.mp4
# --------------------------------------------------
# Frames per second = 24.0
# Total frames = 467
# Going to generate  58  clips
# --------------------------------------------------
# Processing video  Test_Video37.mp4
# --------------------------------------------------
# Frames per second = 30.0
# Total frames = 759
# Going to generate  95  clips
# --------------------------------------------------
# Processing video  Test_Video38.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 714
# Going to generate  89  clips
# --------------------------------------------------
# Processing video  Test_Video39.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 477
# Going to generate  59  clips
# --------------------------------------------------
# Processing video  Test_Video4.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 368
# Going to generate  46  clips
# --------------------------------------------------
# Processing video  Test_Video40.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 320
# Going to generate  40  clips
# --------------------------------------------------
# Processing video  Test_Video41.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 326
# Going to generate  41  clips
# --------------------------------------------------
# Processing video  Test_Video42.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 540
# Going to generate  67  clips
# --------------------------------------------------
# Processing video  Test_Video43.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 750
# Going to generate  94  clips
# --------------------------------------------------
# Processing video  Test_Video44.mp4
# --------------------------------------------------
# Frames per second = 59.94
# Total frames = 1200
# Going to generate  150  clips
# --------------------------------------------------
# Processing video  Test_Video45.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 264
# Going to generate  33  clips
# --------------------------------------------------
# Processing video  Test_Video46.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 902
# Going to generate  113  clips
# --------------------------------------------------
# Processing video  Test_Video47.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 180
# Going to generate  22  clips
# --------------------------------------------------
# Processing video  Test_Video48.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 542
# Going to generate  68  clips
# --------------------------------------------------
# Processing video  Test_Video49.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 494
# Going to generate  62  clips
# --------------------------------------------------
# Processing video  Test_Video5.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 886
# Going to generate  111  clips
# --------------------------------------------------
# Processing video  Test_Video51.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 750
# Going to generate  94  clips
# --------------------------------------------------
# Processing video  Test_Video52.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 296
# Going to generate  37  clips
# --------------------------------------------------
# Processing video  Test_Video53.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 682
# Going to generate  85  clips
# --------------------------------------------------
# Processing video  Test_Video54.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 810
# Going to generate  101  clips
# --------------------------------------------------
# Processing video  Test_Video55.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 675
# Going to generate  84  clips
# --------------------------------------------------
# Processing video  Test_Video56.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 451
# Going to generate  56  clips
# --------------------------------------------------
# Processing video  Test_Video57.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 793
# Going to generate  99  clips
# --------------------------------------------------
# Processing video  Test_Video58.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 250
# Going to generate  31  clips
# --------------------------------------------------
# Processing video  Test_Video59.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 441
# Going to generate  55  clips
# --------------------------------------------------
# Processing video  Test_Video6.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 268
# Going to generate  33  clips
# --------------------------------------------------
# Processing video  Test_Video60.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 374
# Going to generate  47  clips
# --------------------------------------------------
# Processing video  Test_Video61.mp4
# --------------------------------------------------
# Frames per second = 59.94
# Total frames = 720
# Going to generate  90  clips
# --------------------------------------------------
# Processing video  Test_Video62.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 1497
# Going to generate  187  clips
# --------------------------------------------------
# Processing video  Test_Video63.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 208
# Going to generate  26  clips
# --------------------------------------------------
# Processing video  Test_Video64.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 417
# Going to generate  52  clips
# --------------------------------------------------
# Processing video  Test_Video65.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 450
# Going to generate  56  clips
# --------------------------------------------------
# Processing video  Test_Video66.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 556
# Going to generate  69  clips
# --------------------------------------------------
# Processing video  Test_Video67.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 479
# Going to generate  60  clips
# --------------------------------------------------
# Processing video  Test_Video68.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 350
# Going to generate  44  clips
# --------------------------------------------------
# Processing video  Test_Video69.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 575
# Going to generate  72  clips
# --------------------------------------------------
# Processing video  Test_Video7.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 810
# Going to generate  101  clips
# --------------------------------------------------
# Processing video  Test_Video70.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 1098
# Going to generate  137  clips
# --------------------------------------------------
# Processing video  Test_Video71.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 588
# Going to generate  73  clips
# --------------------------------------------------
# Processing video  Test_Video72.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 407
# Going to generate  51  clips
# --------------------------------------------------
# Processing video  Test_Video73.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 700
# Going to generate  87  clips
# --------------------------------------------------
# Processing video  Test_Video74.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 157
# Going to generate  19  clips
# --------------------------------------------------
# Processing video  Test_Video75.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 301
# Going to generate  37  clips
# --------------------------------------------------
# Processing video  Test_Video76.mp4
# --------------------------------------------------
# Frames per second = 24.0
# Total frames = 1416
# Going to generate  177  clips
# --------------------------------------------------
# Processing video  Test_Video77.mp4
# --------------------------------------------------
# Frames per second = 59.94
# Total frames = 493
# Going to generate  61  clips
# --------------------------------------------------
# Processing video  Test_Video78.mp4
# --------------------------------------------------
# Frames per second = 30.0
# Total frames = 900
# Going to generate  112  clips
# --------------------------------------------------
# Processing video  Test_Video79.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 525
# Going to generate  65  clips
# --------------------------------------------------
# Processing video  Test_Video80.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 499
# Going to generate  62  clips
# --------------------------------------------------
# Processing video  Test_Video81.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 1031
# Going to generate  129  clips
# --------------------------------------------------
# Processing video  Test_Video82.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 346
# Going to generate  43  clips
# --------------------------------------------------
# Processing video  Test_Video83.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 251
# Going to generate  31  clips
# --------------------------------------------------
# Processing video  Test_Video84.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 950
# Going to generate  119  clips
# --------------------------------------------------
# Processing video  Test_Video85.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 764
# Going to generate  95  clips
# --------------------------------------------------
# Processing video  Test_Video86.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 587
# Going to generate  73  clips
# --------------------------------------------------
# Processing video  Test_Video87.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 554
# Going to generate  69  clips
# --------------------------------------------------
# Processing video  Test_Video88.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 433
# Going to generate  54  clips
# --------------------------------------------------
# Processing video  Test_Video89.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 220
# Going to generate  27  clips
# --------------------------------------------------
# Processing video  Test_Video9.mp4
# --------------------------------------------------
# Frames per second = 30.0
# Total frames = 503
# Going to generate  63  clips
# --------------------------------------------------
# Processing video  Test_Video90.mp4
# --------------------------------------------------
# Frames per second = 30.0
# Total frames = 320
# Going to generate  40  clips
# --------------------------------------------------
# Processing video  Test_Video91.mp4
# --------------------------------------------------
# Frames per second = 23.98
# Total frames = 428
# Going to generate  53  clips
# --------------------------------------------------
# Processing video  Test_Video92.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 525
# Going to generate  65  clips
# --------------------------------------------------
# Processing video  Test_Video93.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 698
# Going to generate  87  clips
# --------------------------------------------------
# Processing video  Test_Video94.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 758
# Going to generate  95  clips
# --------------------------------------------------
# Processing video  Test_Video95.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 371
# Going to generate  46  clips
# --------------------------------------------------
# Processing video  Test_Video96.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 650
# Going to generate  81  clips
# --------------------------------------------------
# Processing video  Test_Video97.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 320
# Going to generate  40  clips
# --------------------------------------------------
# Processing video  Test_Video98.mp4
# --------------------------------------------------
# Frames per second = 25.0
# Total frames = 379
# Going to generate  47  clips
# --------------------------------------------------
# Processing video  Test_Video99.mp4
# --------------------------------------------------
# Frames per second = 29.97
# Total frames = 690
# Going to generate  86  clips
# Accuracy: 0.7279
# Precision: 1.0000
# Recall: 0.6970
# F-score: 0.8214
# Detection mean error: 0.9674
# Detection delay: 0.9839
# Final score numerator: 0.6857
# Using cache found in C:\Users\crist/.cache\torch\hub\facebookresearch_pytorchvideo_main
